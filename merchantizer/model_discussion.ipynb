# %%
from metaflow import Flow, get_metadata

print("Current metadata provider: %s" % get_metadata())
# Out:
# Current metadata provider: local@/Users/sonoffungdark/Projects/merchantizer/merchantizer

# %% [markdown]
# ### What happened in model.py?
# The code generated embeddings in preparation for the BERT topic modeling task. It then goes into the model fitting step, leveraging a sample of the cleaned description data.

# %%
run = Flow('MerchantModelFlow').latest_successful_run
print("Using run: %s" % str(run))

topic_info_df = run.data.topic_info_df
# Out:
# Using run: Run('MerchantModelFlow/1714402285381590')

# %% [markdown]
# ### Topic Model Report
# Let's first take a look at the specified topics. The first 24 were specified in the code, and the following (those Names prepended by a number) are what the model found as topics on its own. An example is topic 25. When you look at the Representation_Docs column for it, it appears to be honing in on grocery patterns.

# %%
topic_info_df
# Out:
#     Topic  Count                                 Name  \
# 0       0  11413                              walmart
# 1       1   6592                              cashapp
# 2       2   5070                            mcdonalds
# 3       3   3124                                 uber
# 4       4   2430                            starbucks
# 5       5   2318                                apple
# 6       6   2260                             7-eleven
# 7       7   2260                               amazon
# 8       8   2060                            taco-bell
# 9       9   1973                             doordash
# 10     10   1922                               google
# 11     11   1917                           365-market
# 12     12   1571                                shell
# 13     13   1552                       dollar-general
# 14     14   1551                             circle-k
# 15     15   1391                               square
# 16     16   1283                                 lyft
# 17     17   1125                              chevron
# 18     18   1034                               wendys
# 19     19    992                                exxon
# 20     20    879                                toast
# 21     21    758                        family-dollar
# 22     22    715                               target
# 23     23    615                          dollar-tree
# 24     24  27498              -1_ca_caus_dave_angeles
# 25     25   1480         0_grocery_atlanta_food_foods
# 26     26   1069              1_flus_miami_fl_florida
# 27     27    809    2_liquors_liquor_beverage_bourbon
# 28     28    722  3_smokeshop_smokehouse_smokes_smoke
# 29     29    718          4_chicago_ilus_mius_detroit
#
#                                        Representation  \
# 0   [mart, wal, supermarket, stores, grocery, stor...
# 1   [cashapp, cash, adoordash, apple, paymentoast,...
# 2   [mcdonalds, burgers, burger, kfc, dunkin, frys...
# 3   [uber, trip, help, ride, transit, postmates, t...
# 4   [starbucks, cafe, 800, kroger, coffee, 782, ba...
# 5   [apple, caus, bill, ca, mac, macs, mous, 7733,...
# 6   [seven, eleven, 7th, 7eleven, 7eletxus, 11, 07...
# 7   [mktp, amazon, us, netflix, paypal, kindle, bi...
# 8   [tacobell, taco, tacos, bell, tasty, bells, do...
# 9   [doordash, mcdonalds, doordashdashpass, caus, ...
# 10  [google, caus, storage, gaus, ca, helppay, gbr...
# 11  [market, market32, mymarketrewards, marketplac...
# 12  [shell, portland, puff, bay, beach, playstatio...
# 13  [dollar, dollartre, generaln, generalnera, gen...
# 14  [circle, 01344, k1, 09528, 01590, 23378, 01677...
# 15  [square, quickquack, gosquare, corner, queens,...
# 16  [lyft, 5pm, ride, 4pm, rides, caus, fri, 5am, ...
# 17  [chevron, petrol, gasoline, petroleum, chegg, ...
# 18  [wendys, wendy, dennys, krispy, hortons, daves...
# 19  [exxon, exxonmobil, petroleum, oil, expres, fu...
# 20  [toast, toasted, bread, sandwich, snack, loaf,...
# 21  [dollar, family, cousins, coin, dads, goodwill...
# 22  [target, hit, shooting, mart, goodstop, store,...
# 23  [dollartree, dollar, dollartre, tree, billingt...
# 24  [ca, caus, dave, angeles, playstation, txus, i...
# 25  [grocery, atlanta, food, foods, grocers, super...
# 26  [flus, miami, fl, florida, cmsvend, tampa, jac...
# 27  [liquors, liquor, beverage, bourbon, beverages...
# 28  [smokeshop, smokehouse, smokes, smoke, smoker,...
# 29  [chicago, ilus, mius, detroit, il, mi, wius, m...
#
#                                   Representative_Docs
# 0    [wal-mart mart , wal-mart mart , wal-mart mart ]
# 1   [apple cash balance adoordash , apple cash bal...
# 2                 [burger-king, mcdonalds, mcdonalds]
# 3   [uber   trip            help.uber , uber   tri...
# 4   [starbucks 800-782-7282, starbucks 800-782-728...
# 5   [apple /bill         866-712-7753 caus, apple ...
# 6                      [7-eleven, 7-eleven, 7-eleven]
# 7   [amazon  mktp us, amazon  mktp us           am...
# 8   [doordash*taco-bell     www.doordash.caus, doo...
# 9   [doordash  doordash mcdonalds  855-973-1040 ca...
# 10  [google *google storage 855-836-3987 caus, goo...
# 11  [365-market j 888 432-3, 365-market j 888 432-...
# 12                              [shell, shell, shell]
# 13  [dollar-general market place, dollar-general d...
# 14  [circle-k # 01344, circle 1 market       , cir...
# 15  [square  *square  weebly, square  inc., square...
# 16  [lyft   ride tue 4pm    855-865-9553 caus, lyf...
# 17  [chevron gas station      , chevron, chevron g...
# 18                           [wendys, wendys, wendys]
# 19  [bell exxon, exxon food mart       , exxon t-s...
# 20  [toast * taco taco, toast * toast fine food & ...
# 21  [family-dollar #, family-dollar #, family-doll...
# 22      [target   *, target   *         , target   *]
# 23            [dollar-tree, dollar-tree, dollar-tree]
# 24  [playstation network    800-345-7669 caus, dav...
# 25  [j&b food mart          monroe       gaus, foo...
# 26  [cmsvend*cv miami       miami        flus, spe...
# 27     [t liquor, r s liquor            , j&j liquor]
# 28               [smoke shop, smoke shop, smoke shop]
# 29  [bp#9404930north ave bp chicago      ilus, bp#...

# %% [markdown]
# ### View Predictions Across 3 Important Merchants

# %%
fit_prediction_df = run.data.fit_prediction_df

# %%
fit_prediction_df[fit_prediction_df["cleaned_description"].str.contains("target")]
# Out:
#                    merchantName                               description  \
# 1324612                     NaN  TARGET        00008151 FORT LAUDERDAFLUS
# 1475940                     NaN  TARGET        00018226 CLIFTON      NJUS
# 1370972                     NaN  TARGET        00022459 ONTARIO      CAUS
# 1127934  TARGET        00007567                    TARGET        00007567
# 2773579   TARGET T- 855 E Birch                     TARGET T- 855 E Birch
# ...                         ...                                       ...
# 865349                      NaN  TARGET T- 16806 N 7th  Phoenix        AZ
# 7259809  TARGET        00023457                    TARGET        00023457
# 8870552  TARGET        00010074                    TARGET        00010074
# 6958731  TARGET        00020420                    TARGET        00020420
# 8783486  TARGET        00011726                    TARGET        00011726
#
#                               cleaned_description pruned_description  \
# 1324612  target        00008151 fort lauderdaflus             target
# 1475940  target        00018226 clifton      njus             target
# 1370972  target        00022459 ontario      caus             target
# 1127934                    target        00007567             target
# 2773579                     target t- 855 e birch             target
# ...                                           ...                ...
# 865349   target t- 16806 n 7th  phoenix        az             target
# 7259809                    target        00023457             target
# 8870552                    target        00010074             target
# 6958731                    target        00020420             target
# 8783486                    target        00011726             target
#
#          predicted_topic predicted_merchant
# 1324612               22             target
# 1475940               22             target
# 1370972               22             target
# 1127934               22             target
# 2773579               22             target
# ...                  ...                ...
# 865349                22             target
# 7259809               22             target
# 8870552               22             target
# 6958731               22             target
# 8783486               22             target
#
# [576 rows x 6 columns]

# %%
fit_prediction_df[fit_prediction_df["cleaned_description"].str.contains("doordash")]
# Out:
#                       merchantName                               description  \
# 9059513     DD DOORDASH SHARKSFIS                     DD DOORDASH SHARKSFIS
# 3359018                        NaN  DD *DOORDASH PETSMART  SAN FRANCISCO CA
# 8162999     CASH APP*GILLIS*ADD                       CASH APP*GILLIS*ADD
# 1120582     DD/BR #304762 Q35                         DD/BR #304762 Q35
# 3582987                        NaN  DOORDASH*AUNTIE ANNES  WWW.DOORDASH.CAUS
# ...                            ...                                       ...
# 3832407     GETISLANDDREAMSDISCOUN                    GETISLANDDREAMSDISCOUN
# 2036127                        NaN  DD DOORDASH LITTLECAE  855-973-1040 CAUS
# 7258987  DD DOORDASH OHFISHSUS                     DD DOORDASH OHFISHSUS
# 5969347                        NaN  DD DOORDASH PANDAEXPR  855-973-1040 CAUS
# 7186902                        NaN  DD DOORDASH DASHMART   855-973-1040 CAUS
#
#                                        cleaned_description  \
# 9059513                      doordash  doordash sharksfis
# 3359018  doordash  *doordash petoast mart  san francisc...
# 8162999                      cashapp *gillis*adoordash
# 1120582                      doordash /br #304762 q35
# 3582987           doordash*auntie annes  www.doordash.caus
# ...                                                    ...
# 3832407                                  getislandoordash
# 2036127    doordash  doordash littlecae  855-973-1040 caus
# 7258987                   doordash  doordash ohfishsus
# 5969347    doordash  doordash pandaexpr  855-973-1040 caus
# 7186902    doordash  doordash dashmart   855-973-1040 caus
#
#                                pruned_description  predicted_topic  \
# 9059513                                  doordash                9
# 3359018                                  doordash                9
# 8162999                                   cashapp                1
# 1120582                                  doordash                9
# 3582987  doordash*auntie annes  www.doordash.caus                9
# ...                                           ...              ...
# 3832407                         getislandoordash                 9
# 2036127                                  doordash                9
# 7258987                                  doordash                9
# 5969347                                  doordash                9
# 7186902                                  doordash                9
#
#         predicted_merchant
# 9059513           doordash
# 3359018           doordash
# 8162999            cashapp
# 1120582           doordash
# 3582987           doordash
# ...                    ...
# 3832407           doordash
# 2036127           doordash
# 7258987           doordash
# 5969347           doordash
# 7186902           doordash
#
# [3005 rows x 6 columns]

# %%
fit_prediction_df[fit_prediction_df["cleaned_description"].str.contains("amazon")]
# Out:
#                    merchantName                               description  \
# 2134722  Amazon Prime*TO5QL1NO2                    Amazon Prime*TO5QL1NO2
# 3481542                     NaN  GOOGLE *Amazon Mobile  855-836-3987 CAUS
# 4058636    AMAZON.COM*JZ20R4EC3                      AMAZON.COM*JZ20R4EC3
# 3988415                     NaN  AMZN Mktp US*J885B3L43 Amzn.com/billWAUS
# 6260500                     NaN  AMZN Mktp US*TP3KV8UF2 Amzn.com/billWAUS
# ...                         ...                                       ...
# 2838281  AMZN Mktp US*E57T75SB3                    AMZN Mktp US*E57T75SB3
# 2206441                     NaN  Amazon Prime*ET9S17TC3 Amzn.com/billWAUS
# 4484013                     NaN  AMZN Mktp US*SM9UA8ZV3 Amzn.com/billWAUS
# 7691322                     NaN  AMZN Mktp US*S74AC7463 Amzn.com/billWAUS
# 9187291                     NaN  Audible*OG6HQ3J33      Amzn.com/billNJUS
#
#                                  cleaned_description  \
# 2134722                       amazon prime*to5ql1no2
# 3481542     google *amazon mobile  855-836-3987 caus
# 4058636                            amazon *jz20r4ec3
# 3988415  amazon  mktp us*j885b3l43 amazon  /billwaus
# 6260500  amazon  mktp us*tp3kv8uf2 amazon  /billwaus
# ...                                              ...
# 2838281                    amazon  mktp us*e57t75sb3
# 2206441     amazon prime*et9s17tc3 amazon  /billwaus
# 4484013  amazon  mktp us*sm9ua8zv3 amazon  /billwaus
# 7691322  amazon  mktp us*s74ac7463 amazon  /billwaus
# 9187291     audible*og6hq3j33      amazon  /billnjus
#
#                                pruned_description  predicted_topic  \
# 2134722                                    amazon                7
# 3481542                                    google                7
# 4058636                                    amazon                7
# 3988415                                    amazon                7
# 6260500                                    amazon                7
# ...                                           ...              ...
# 2838281                                    amazon                7
# 2206441                                    amazon                7
# 4484013                                    amazon                7
# 7691322                                    amazon                7
# 9187291  audible*og6hq3j33      amazon  /billnjus                7
#
#         predicted_merchant
# 2134722             amazon
# 3481542             amazon
# 4058636             amazon
# 3988415             amazon
# 6260500             amazon
# ...                    ...
# 2838281             amazon
# 2206441             amazon
# 4484013             amazon
# 7691322             amazon
# 9187291             amazon
#
# [1753 rows x 6 columns]

# %% [markdown]
# ### Notable Issues/Key Concerns
# * Again, we see the doordashxcashapp problem rearing its ugly head. We had already addressed this with a TODO in the clean.py file, so that could be sorted in the future. I would recommend an investigation on multi-merchant descriptions.
# * I would also consider looking into stopgap words that exist in merchant names. 365 Market is a good example, the results would likely be better if Market was removed from the 365 descriptions, thereby creating seperation between it and all the other market descriptions.
# * My biggest concern was how computationally costly the bertopic package was. I had to downsample to 100 thousand from 10 million. About halfway through my task, I spun up a large GPU in the cloud and began running the same code with 1 million records. It is still running (~3 hours in). I would recommend an investigation into various strategies that could be leveraged (GPU acceleration, for example), to improve the compute time.
